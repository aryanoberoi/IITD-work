# %%
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel

json_file_path = 'Books.json'

df = pd.read_json(json_file_path, lines=True, nrows=10000)

df.dropna(subset=['reviewText'], inplace=True)


print(df)
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 0           5     False  08 12, 2005  A1C6M8LCIX4M6M  0001713353
# 1           5     False  03 30, 2005  A1REUF3A1YCPHM  0001713353
# 2           5     False   04 4, 2004   A1YRBRK2XM5D5  0001713353
# 3           5     False  02 21, 2004  A1V8ZR5P78P4ZU  0001713353
# 4           5      True   10 3, 2016  A2ZB06582NXCIV  0001713353
# ...       ...       ...          ...             ...         ...
# 9995        5      True  07 25, 2015   ANKDQJ3KX32RV  0001844423
# 9996        5      True  07 24, 2015  A1RZ3DG6SN9ITC  0001844423
# 9997        5     False  07 23, 2015  A2EXJJG1UN0UC8  0001844423
# 9998        4      True  07 23, 2015   A8ZVHTO78LMID  0001844423
# 9999        5      True  07 22, 2015   AZQ76U2XA6NLT  0001844423
#
#                                style       reviewerName  \
# 0          {'Format:': ' Paperback'}           June Bug
# 1          {'Format:': ' Hardcover'}        TW Ervin II
# 2          {'Format:': ' Hardcover'}  Rebecca L. Menner
# 3          {'Format:': ' Hardcover'}        Mindy Stone
# 4                                NaN         B. Deniger
# ...                              ...                ...
# 9995  {'Format:': ' Kindle Edition'}             vwstud
# 9996        {'Format:': ' Audio CD'}               Adam
# 9997  {'Format:': ' Kindle Edition'}   Sean A Harrelson
# 9998  {'Format:': ' Kindle Edition'}             Ramona
# 9999       {'Format:': ' Paperback'}         Samuel Lee
#
#                                              reviewText  \
# 0     This book is a winner with both of my boys.  T...
# 1     The King, the Mice and the Cheese by Nancy Gur...
# 2     My daughter got her first copy from her great-...
# 3     I remember this book from when I was a child a...
# 4     Just as I remembered it, one of my favorites f...
# ...                                                 ...
# 9995  As expected, great. C.S. Lewis never fails to ...
# 9996  We listened to several of these on a long road...
# 9997  Aslan destroyed Narnia and sent Eustace and Pe...
# 9998          This is my favorite Chronicles of Narnia.
# 9999  Read this book as a child and absolutely loved...
#
#                                                 summary  unixReviewTime  vote  \
# 0                                   Children's favorite      1123804800   NaN
# 1             A story children will love and learn from      1112140800   NaN
# 2                                            Third copy      1081036800   5.0
# 3                                Graphically Wonderful!      1077321600   NaN
# 4     Great condition, very happy to have this to sh...      1475452800   NaN
# ...                                                 ...             ...   ...
# 9995                                            Caspian      1437782400   NaN
# 9996                                   Great Narrators!      1437696000   NaN
# 9997                                               epic      1437609600   NaN
# 9998                                         A favorite      1437609600   NaN
# 9999                                           Perfect!      1437523200   NaN
#
#      image
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 9995   NaN
# 9996   NaN
# 9997   NaN
# 9998   NaN
# 9999   NaN
#
# [9997 rows x 12 columns]

# %%
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')


def get_bert_embedding(text):
    
    tokens = tokenizer.encode(text, add_special_tokens=True, max_length=512, truncation=True)

    # Convert tokens to tensor
    input_ids = torch.tensor(tokens).unsqueeze(0)

    # getting hidden states
    with torch.no_grad():
        outputs = model(input_ids)

    # Embedding of CLS token
    cls_embedding = outputs.last_hidden_state[:, 0, :]

    return cls_embedding.numpy()


df['BERT_Embedding'] = df['reviewText'].apply(get_bert_embedding)

print(df)
